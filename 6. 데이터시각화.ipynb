# %% [markdown]
# # 데이터 시각화
#
# - 데이터를 분석한 결과를 쉽게 이해할 수 있도록 표현하여 전달하는 것
# - 데이터의 시각화가 필요한 이유
#     - 많은 양의 데이터를 한 눈에 살펴볼 수 있음
#     - 전문 지식이 없더라도 누구나 쉽게 데이터를 인지하고 사용할 수 있음
#     - 단순한 데이터의 요약이나 나열보다 더 정확한 데이터 분석 결과를 얻을 수 있음
#     - 단순한 데이터에서는 알 수 없었던 중요한 정보를 파악할 수 있음
#
# - 파이썬의 시각화 라이브러리
#     - matplotlib, seaborn, wordcloud

# %% [markdown]
# # 그래프란
#
# - 서로 연관성이 있는 1개 또는 그 이상의 양에 대한 상대 값을 도형으로 나타내는 것
#
# - 데이터의 갯수, 데이터의 종류에 따른 그래프의 종류
#     - 일변량(데이터 개수가 1개)
#         - 연속형
#             - 히스토그램(histogram)
#             - 상자수염 그래프(boxplot)
#             - 바이올린 그래프(violin)
#             - 커널 밀도 그래프(kernel density curve)
#
#         - 범주형
#             - 막대 그래프(bar chart)
#             - 파이 그래프(pie chart)
#
#     - 다변량(데이터 개수가 2개 이상)
#         - 연속형
#             - 산점도(scatter plot)
#             - 선 그래프(line chart)
#             - 시계열 그래프
#
#         - 범주형
#             - 모자이크 그래프(mosaic graph)
#             - Tree Map 그래프

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from matplotlib import font_manager, rc
import matplotlib
font_path = 'C:/Windows/Fonts/malgun.ttf'
font_name = font_manager.FontProperties(fname = font_path).get_name()
rc('font', family=font_name)

# %% [markdown]
# # 기본 그래프

# %%
plt.plot([1, 2, 3, 4])
plt.ylabel("y축")
plt.show() # 그리고 있던 작업물을 보여줘라

# %% [markdown]
# - 리스트의 값이 y값이라고 가정하고 x값을 자동으로 생성([0, 1, 2, 3])

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
plt.plot([1,2,3,4], [1,4,9,16], "ro") # 기본은 "b-" = 블루 실선
plt.axis([0,6,0,20]) # xmin, xmax, ymin, ymax
plt.show()

# %% [markdown]
# ## 범례 추가

# %%
plt.plot([1, 2, 3], [1, 4, 9])
plt.plot([2, 3, 4], [5, 6, 7])
plt.xlabel("Sequence")
plt.ylabel("Time(secs)")
plt.title("Experiment Result")
plt.legend(["Mouse", "Cat"])
plt.show()

# %% [markdown]
# # 여러 개의 그래프 그리기

# %%
t = np.arange(0, 5, 0.2) # 0부터 0.2 씩 올라가는 것

# %%
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
plt.plot(t, t, "r--", t, t ** 2, "bs", t, t ** 3, "g^") # -- 선, s 네모, ^ 세모
plt.show()

# %% [markdown]
# <img src = "./img/matplotlib_set_marker.png">

# %% [markdown]
# - 문제
# - 2010년부터 2018년까지 매년 수집한 데이터가 아래와 같다. 이를 matplotlib의 plot 함수를 사용하여 직선 그래프로 나타내시오
# - x축의 눈금은 년도를 나타내는 숫자로 표시하시오
# - 직선은 빨간색, 실선으로, 마커는 다이아몬드형으로 표시하시오

# %%
data = [102, 105, 108, 129, 166, 170, 181, 182, 182]

# %%
year = range(2010, 2019)

plt.plot(year, data, "r-D")
plt.show()

# %% [markdown]
# # 그래프 영역 채우기

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.xlabel("x축")
plt.ylabel("y축")
plt.fill_between(x[1:3], y[1:3], alpha = 0.5) # alpha = 투명도

plt.show()

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y)
plt.xlabel("x축")
plt.ylabel("y축")
plt.fill_betweenx(y[1:3], x[1:3], color="pink", alpha=0.5) #fill_betweenx(y, x) = y축에 색칠이 됨

plt.show()

# %% [markdown]
# # 두 그래프 사이 영역 채우기

# %%
x = [1, 2,3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel("x축")
plt.ylabel("y축")
plt.fill_between(x[1:3], y1[1:3], y2[1:3], color="lightgray", alpha=0.5)

plt.show()

# %% [markdown]
# # 임의의 영역 채우기

# %%
x = [1, 2,3, 4]
y1 = [1, 4, 9, 16]
y2 = [1, 2, 4, 8]

plt.plot(x, y1)
plt.plot(x, y2)
plt.xlabel("x축")
plt.ylabel("y축")
plt.fill([1.9, 1.9, 3.1, 3.1], [2, 5, 11, 8], color="lightgray", alpha=0.5) # [1,9 ~ 3.1] = 도형의 크기

plt.show()

# %% [markdown]
# # 격자 설정

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a** 3, color = "springgreen", marker = "^", markersize = 9)
plt.grid(True) # 격자무늬

plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a** 3, color = "springgreen", marker = "^", markersize = 9)
plt.grid(True, axis = "y")

plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a** 3, color = "springgreen", marker = "^", markersize = 9)
plt.grid(True, axis = "y", color="red", alpha=0.5, linestyle="--")

plt.show()

# %% [markdown]
# # 눈금 표시

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a** 3, color = "springgreen", marker = "^", markersize = 9)
plt.xticks([0, 1, 2])
plt.yticks(np.arange(1,6))

plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a** 3, color = "springgreen", marker = "^", markersize = 9)
plt.xticks(np.arange(0, 2, 0.2), labels=["Jan", "", "Feb", "", "Mar", "", "May", "", "June", ""])
plt.yticks(np.arange(0, 7), ("0", "1GB", "2GB", "3GB", "4GB", "5GB", "6GB"))
plt.show()

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a** 3, color = "springgreen", marker = "^", markersize = 9)
plt.xticks(np.arange(0, 2, 0.2), labels=["Jan", "", "Feb", "", "Mar", "", "May", "", "June", ""])
plt.yticks(np.arange(0, 7), ("0", "1GB", "2GB", "3GB", "4GB", "5GB", "6GB"))

plt.tick_params(axis="x", direction="in", length=3, pad=6, labelsize=14, labelcolor="green", top=True)
plt.tick_params(axis="y", direction="inout", length=10, pad=15, labelsize=12, width=2, color="r")

# axis에 x,y 둘 다 들어갈 수 있음
# pad = 눈금거리
# top = True = 눈금 표시 위치, top, bottom, right, left

plt.show()

# %% [markdown]
# - tick_params() : 눈금의 스타일을 지정
#     - axis : 설정이 적용될 축을 지정. x, y, both 중 선택
#     - direction : 눈금이 안에서 표시될지 밖에서 표시될지. in, out, inout
#     - length : 눈금의 길이
#     - pad : 눈금과 레이블과의 거리
#     - labelsize : 레이블의 크기
#     - labelcolor : 레이블의 색상
#     - top/bottom/left/right : 눈금이 표시될 위치 선택
#     - width : 눈금의 너비
#     - color : 눈금의 색상

# %% [markdown]
# # 제목 설정

# %%
a = np.arange(0, 2, 0.2)

plt.plot(a, a, "bo")
plt.plot(a, a ** 2, color = "#e35f62", marker = "*", linewidth = 2)
plt.plot(a, a** 3, color = "springgreen", marker = "^", markersize = 9)

plt.grid(True, axis="y", color="gray", alpha=0.5, linestyle="--")
plt.tick_params(axis="both", direction="in", length=3, pad=6, labelsize=14)
plt.title("샘플 그래프", loc="right", pad=20)

plt.show()

# %% [markdown]
# # 꺾은 선 그래프
#
# - 연속적으로 변화하는 데이터를 살펴보고자 할 때 주로 사용
#     - 시간에 따른 데이터의 연속적인 변화량을 관찰할 때
#         - ex) 시간에 따른 기온의 변화, 물을 끓인 다음 식히면서 시간에 따른 물의 온도 변화 등

# %%
df = pd.read_csv("주요발생국가주간동향(4월2째주).csv", index_col = "국가")
df.head()
# Out:
#        4월06일   4월07일   4월08일   4월09일   4월10일   4월11일   4월12일
# 국가
# 미국    335524  364723  387547  424945  461437  495535  524903
# 스페인   130709  135032  140510  146690  152446  157022  161852
# 이탈리아  128948  132547  135586  139422  143626  147577  152271
# 독일    100024  102453  107591  112113  118181  122171  124908
# 프랑스    70478   74390   78167   82048   86334   90276   93790

# %%
df.columns
# Out:
# Index(['4월06일', '4월07일', '4월08일', '4월09일', '4월10일', '4월11일', '4월12일'], dtype='object')

# %% [markdown]
# - 4월 6일 코로나 발생 건수를 꺾은 선 그래프로 그리기
